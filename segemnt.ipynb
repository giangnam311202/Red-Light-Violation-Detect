# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196  Python-3.12.0 torch-2.3.1+cpu CPU (12th Gen Intel Core(TM) i7-12700H)
# Setup complete  (20 CPUs, 15.6 GB RAM, 397.6/449.3 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="lSySzVMOpssZPXOXIkim")
project = rf.workspace("traffic-violation-detected").project("segment-dataset")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# [notice] A new release of pip is available: 24.1 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Segment-dataset-1 in yolov8:: 100%|██████████| 5140/5140 [00:03<00:00, 1390.55it/s]

# %%
# !yolo task=segment mode=train model=yolov8s-seg.pt data='/content/Segment-dataset-1/data.yaml' epochs=10 imgsz=640
# Out:
# ...
#
#   0%|          | 0.00/22.8M [00:00<?, ?B/s]
#   2%|▏         | 512k/22.8M [00:00<00:05, 4.22MB/s]
#  13%|█▎        | 3.00M/22.8M [00:00<00:01, 16.0MB/s]
#  24%|██▎       | 5.38M/22.8M [00:00<00:01, 17.2MB/s]
#  32%|███▏      | 7.25M/22.8M [00:00<00:00, 17.5MB/s]
#  39%|███▉      | 9.00M/22.8M [00:00<00:00, 14.8MB/s]
#  46%|████▌     | 10.5M/22.8M [00:00<00:00, 13.4MB/s]
#  52%|█████▏    | 11.9M/22.8M [00:00<00:01, 10.6MB/s]
#  57%|█████▋    | 13.0M/22.8M [00:01<00:01, 6.11MB/s]
#  61%|██████    | 13.9M/22.8M [00:01<00:01, 4.70MB/s]
#  64%|██████▍   | 14.6M/22.8M [00:02<00:02, 4.15MB/s]
#  67%|██████▋   | 15.2M/22.8M [00:02<00:02, 3.87MB/s]
#  69%|██████▉   | 15.8M/22.8M [00:02<00:01, 3.71MB/s]
#  71%|███████▏  | 16.2M/22.8M [00:02<00:01, 3.56MB/s]
#  73%|███████▎  | 16.6M/22.8M [00:02<00:01, 3.54MB/s]
#  75%|███████▍  | 17.0M/22.8M [00:02<00:01, 3.53MB/s]
#  76%|███████▌  | 17.4M/22.8M [00:02<00:01, 3.55MB/s]
#  78%|███████▊  | 17.8M/22.8M [00:03<00:01, 3.53MB/s]
# ...

# %%
Image(filename=f'/content/runs/segment/train2/confusion_matrix.png', width=600)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Image(filename=f'/content/runs/segment/train2/confusion_matrix.png', width=600)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\display.py:327, in DisplayObject.__init__(self, data, url, filename, metadata)
#     324 elif self.metadata is None:
#     325     self.metadata = {}
# --> 327 self.reload()
# ...

# %%
Image(filename=f'/content/runs/segment/train2/val_batch0_pred.jpg', width=600)

# %%
# !yolo task=segment model=predict model='/content/runs/segment/train2/weights/best.pt' conf=0.25 source=/content/dendo_1.mp4
